# %%
"""
Setting for google colab
"""
# The path of your project on google drive
path_project = "/content/drive/MyDrive/cartography msc/Thesis TUM 2024/momepy/"

# Connect colab with google drive
from google.colab import drive
drive.mount('/content/drive')

# Set the project path as current working directory
import os
os.chdir(path_project)
print("Current files under the working directory:", os.listdir())

# %% [markdown]
# # Imports

# %%
# !pip install momepy
# !pip install osmnx
# !pip install PyDrive
# !pip install clustergram
# !pip install folium matplotlib mapclassify
# !pip install shapely
# !pip install matplotlib-scalebar
# !pip install basemap
# !pip install bokeh
# !pip install seaborn
# !pip install libpysal

import pandas as pd
import geopandas as gpd
import networkx as nx
import numpy as np
import momepy as mm
import momepy
import pyproj
import osmnx as ox
import libpysal
from shapely.geometry import box
from time import time
from clustergram import Clustergram
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib_scalebar.scalebar import ScaleBar
from mpl_toolkits.basemap import Basemap
from bokeh.io import output_notebook
from bokeh.plotting import show
from scipy.spatial.distance import euclidean
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, classification_report
import seaborn as sns
from libpysal import graph

from shapely import LineString
from shapely.geometry import Point

# %% [markdown]
# # Getting Data Locally (update to support collab or other more shareable/cloud based service)

# %%
import sys
sys.path.append(r"C:\Users\miles\favela_analysis\src")
from tessellation import perform_perfect_tessellation, print_perfect_tessellation_report

try:
    buildings_path = r"C:\Users\miles\OneDrive\Desktop\school\UROP\Data\best_test_set.shp" #DATA SOURCE GOES HERE
    clean_buildings, tessellation, excluded_buildings, report = perform_perfect_tessellation(
        buildings_path,
        min_area=1.0,
        buffer_dist=100,
        max_iterations=10
    )

    print_perfect_tessellation_report(report)

except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# Tessellation Report:
# --------------------------------------------------
# Original building count: 6777
# Excluded building count: 4
# Final building count: 6773
# Tessellation cell count: 6773
#
# Reasons for exclusion:
#   - tessellation_failure: 4 buildings

# %%
#classes
from building_metrics_calculator import BuildingMetricsCalculator
from building_metrics_plotter import BuildingMetricsPlotter

output_dir = r"C:\Users\miles\favela_analysis\output"

# Initialize calculator and run calculations
calculator = BuildingMetricsCalculator(clean_buildings, tessellation, output_dir) #BuildingMetricsCalculator Class
calculator.run_all_calculations()

# # Initialize and run plotter -> values can be plotted afterwards
# plotter = BuildingMetricsPlotter(calculator, output_dir)
# plotter.plot_all()
# Out:
# C:\Users\miles\.julia\conda\3\x86_64\Lib\site-packages\momepy\functional\_distribution.py:285: UserWarning: The indices of the two GeoSeries are different.
#   (geoms.distance(geometry.geometry, align=True)).groupby(level=0).mean()
# C:\Users\miles\.julia\conda\3\x86_64\Lib\site-packages\momepy\functional\_shape.py:890: RuntimeWarning: invalid value encountered in arccos
#   angles = np.arccos(cosine_angle)
# C:\Users\miles\.julia\conda\3\x86_64\Lib\site-packages\momepy\functional\_shape.py:890: RuntimeWarning: invalid value encountered in arccos
#   angles = np.arccos(cosine_angle)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       7 # Initialize calculator and run calculations
#       8 calculator = BuildingMetricsCalculator(clean_buildings, tessellation, output_dir) #BuildingMetricsCalculator Class
# ----> 9 calculator.run_all_calculations()
#
# ...

# %%
# print(clean_buildings.head())

print(tessellation.head())

# %%
f, ax = plt.subplots(figsize=(10, 10))
tessellation.plot(ax=ax, edgecolor='white', linewidth=0.5, facecolor='blue', alpha=.7)
clean_buildings.plot(ax=ax, color='white', alpha=.7)
plt.title('Tessellation out of OSM building footprints')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Spatial Joint MM and TP

# %%
from spatial_join import create_complete_buildings, create_joined_gdf

centroids_gdf = calculator.centroids_gdf

# complete_buildings = create_complete_buildings(clean_buildings, centroids_gdf, tessellation)

joined_gdf = create_joined_gdf(clean_buildings, centroids_gdf, tessellation)

# %% [markdown]
# # GROUND TRUTH DATA

# %%
from ground_truth import classify_and_analyze_favelas

try:
    classified_buildings, analysis = classify_and_analyze_favelas(
        clean_buildings,
        type_column='nome_count'
    )

    ground_truth_gdf = classified_buildings

    # merge buildings
    clean_buildings['label'] = classified_buildings['label']

    plt.show()

except Exception as e:
    print(f"Error during classification analysis: {str(e)}")
# Out:
# === Favela Classification Analysis ===
# Total buildings: 6773
# Favela buildings: 1974 (29.1%)
# Non-favela buildings: 4799
#
# Building type distribution:
# 1.0: 1960 buildings
# 2.0: 14 buildings

# %% [markdown]
# # XG Boost Classification

# %%
print(ground_truth_gdf.head())
# Out:
#       FID  cod_unico  cod_projec               Tipo  nome_count  \
# 0  462396    1701347     1701347  A101 - EDIFICACAO         NaN
# 1  462983    2088444     2088444  A101 - EDIFICACAO         NaN
# 2  463639    2088105     2088105  A101 - EDIFICACAO         NaN
# 3  463644    2088462     2088462  A113 - CONSTRUCAO         NaN
# 4  464245    1701181     1701181  A101 - EDIFICACAO         NaN
#
#                                             geometry  uID       label  \
# 0  POLYGON Z ((674719.851 7473392.457 34.780, 674...    0  not-favela
# 1  POLYGON Z ((674511.734 7473366.383 18.280, 674...    1  not-favela
# 2  POLYGON Z ((674552.094 7473313.461 19.650, 674...    2  not-favela
# 3  POLYGON Z ((674535.951 7473372.028 21.730, 674...    3  not-favela
# 4  POLYGON Z ((674566.092 7473330.988 27.880, 674...    4  not-favela
#
#          area  perimeter  ...  corners  rect_idx  rectangularity  squareness  \
# 0  195.755659  89.945229  ...       16  0.772736        0.756119    0.161095
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from matplotlib_scalebar.scalebar import ScaleBar

# List of features to be used for training
metrics = ['area', 'perimeter', 'lal', 'neighbour_dist',
           'mean_interbuilding_distance', 'adjacency', 'corners', 'shape_idx',
           'facade_ratio', 'compact_weighted_axis', 'circular_com',
           'squareness', 'square_compact', 'rectangularity', 'rect_idx',
           'perimeter_wall', 'num_neighbors',
           'elongation', 'fractal', 'cwa', 'CAR', 'tes_area', 'shared_walls']

gdf = ground_truth_gdf

# Select features and target
X = gdf[metrics]
y = gdf['label']

# Encode target labels
label_encoder = LabelEncoder()
label_encoder.fit(['not-favela', 'favela'])
y_encoded = label_encoder.transform(y)
y_encoded = 1 - y_encoded #so not-favela = 0, favela = 1
print(pd.Series(y_encoded).value_counts())

# Impute missing values in features (use median)
imputer = SimpleImputer(strategy='median')
X_imputed = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y_encoded, test_size=0.2, random_state=432)

# Train XGBoost Classifier
xgb_model = XGBClassifier(n_estimators=100, random_state=43, eval_metric='logloss')
xgb_model.fit(X_train, y_train)

# Predict on the test set
y_pred = xgb_model.predict(X_test)

# Add predictions to the original GeoDataFrame, converting numeric predictions back to categorical labels
gdf['predicted_label'] = label_encoder.inverse_transform(xgb_model.predict(X_imputed))

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred)*100)
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))

# Feature importance
feature_importances = pd.DataFrame({
    'Feature': metrics,
    'Importance': xgb_model.feature_importances_
}).sort_values(by='Importance', ascending=False)

print("Feature Importances:")
print(feature_importances)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 21
#      18 gdf = ground_truth_gdf
#      20 # Select features and target
# ---> 21 X = gdf[metrics]
#      22 y = gdf['label']
#      24 # Encode target labels
#
# File c:\Users\miles\.julia\conda\3\x86_64\Lib\site-packages\geopandas\geodataframe.py:1459, in GeoDataFrame.__getitem__(self, key)
#    1453 def __getitem__(self, key):
#    1454     """
#    1455     If the result is a column containing only 'geometry', return a
#    1456     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1457     return a GeoDataFrame.
#    1458     """
# -> 1459     result = super().__getitem__(key)
#    1460     # Custom logic to avoid waiting for pandas GH51895
#    1461     # result is not geometry dtype for multi-indexes
#    1462     if (
#    1463         pd.api.types.is_scalar(key)
# ...

# %%
import shap
import numpy as np

# Initialize SHAP explainer
explainer = shap.Explainer(xgb_model, X_imputed)
shap_values = explainer(X_imputed)

# Convert SHAP values to a DataFrame for easier handling
shap_df = pd.DataFrame(shap_values.values, columns=metrics)

# Ensure the index of shap_df matches the index of gdf
shap_df.index = gdf.index

# Add SHAP values to gdf
for feature in metrics:
    gdf[f'shap_{feature}'] = shap_df[feature]

# Check the updated gdf
print(gdf.head())

# %%
import xgboost as xgb
import matplotlib.pyplot as pl

xgb.plot_importance(xgb_model)
pl.title("Feature Importance (Default: Weight)")
pl.show()

# %%
xgb.plot_importance(xgb_model, importance_type="cover")
pl.title('Feature Importance by Cover')
pl.show()

# %%
xgb.plot_importance(xgb_model, importance_type="gain")
pl.title('Feature Importance by Gain')
pl.show()

# %%
shap.initjs()
# 1. SHAP Force Plot for Many Predictions
# Visualize predictions for the first 1000 individuals
X_display = pd.DataFrame(X_imputed, columns=X.columns)  # Ensure proper column names for SHAP

shap.force_plot(
    explainer.expected_value,  # Use scalar directly
    shap_values.values[:1000, :],
    X_display.iloc[:1000, :]
)

# %%
# 2. SHAP Bar Chart of Mean Importance
# Plot the mean SHAP values as a bar chart
shap.summary_plot(shap_values.values, X_display, plot_type="bar")
plt.show()

# %%
# 3. SHAP Summary Plot (Density Scatter Plot)
# Plot the density scatter plot for SHAP values
shap.summary_plot(shap_values.values, X_display)
plt.show()

# %%
# Create SHAP dependence plots for each feature in X_train
for name in X_train.columns:
    shap.dependence_plot(name, shap_values.values, X_imputed, display_features=X_display)

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

shap_pca50 = PCA(n_components=12).fit_transform(shap_values.values[:1000, :])
shap_embedded = TSNE(n_components=2, perplexity=50).fit_transform(shap_values.values[:1000, :])

# %%
from matplotlib.colors import LinearSegmentedColormap

cdict1 = {
    "red": (
        (0.0, 0.11764705882352941, 0.11764705882352941),
        (1.0, 0.9607843137254902, 0.9607843137254902),
    ),
    "green": (
        (0.0, 0.5333333333333333, 0.5333333333333333),
        (1.0, 0.15294117647058825, 0.15294117647058825),
    ),
    "blue": (
        (0.0, 0.8980392156862745, 0.8980392156862745),
        (1.0, 0.3411764705882353, 0.3411764705882353),
    ),
    "alpha": ((0.0, 1, 1), (0.5, 1, 1), (1.0, 1, 1)),
}  # #1E88E5 -> #ff0052
red_blue_solid = LinearSegmentedColormap("RedBlue", cdict1)

# %%
import numpy as np

f = pl.figure(figsize=(5, 5))
pl.scatter(
    shap_embedded[:, 0],
    shap_embedded[:, 1],
    c=shap_values.values[:1000, :].sum(1).astype(np.float64),  # Use .values here
    linewidth=0,
    alpha=1.0,
    cmap=red_blue_solid,
)
cb = pl.colorbar(label="Favela vs Not Favela", aspect=40, orientation="horizontal")
cb.set_alpha(1)
cb.outline.set_linewidth(0)
cb.ax.tick_params("x", length=0)
cb.ax.xaxis.set_label_position("top")
pl.gca().axis("off")
pl.show()

# %%
for feature in ['area', 'perimeter', 'lal', 'neighbour_dist',
           'mean_interbuilding_distance', 'adjacency', 'corners', 'shape_idx',
           'facade_ratio', 'compact_weighted_axis', 'circular_com',
           'squareness', 'square_compact', 'rectangularity', 'rect_idx',
           'perimeter_wall', 'num_neighbors',
           'elongation', 'fractal', 'cwa', 'CAR', 'tes_area', 'shared_walls']:
    f = pl.figure(figsize=(5, 5))
    pl.scatter(
        shap_embedded[:, 0],
        shap_embedded[:, 1],
        c=X[feature].values[:1000].astype(np.float64),
        linewidth=0,
        alpha=1.0,
        cmap=red_blue_solid,
    )
    cb = pl.colorbar(label=feature, aspect=40, orientation="horizontal")
    cb.set_alpha(1)
    cb.outline.set_linewidth(0)
    cb.ax.tick_params("x", length=0)
    cb.ax.xaxis.set_label_position("top")
    pl.gca().axis("off")
    pl.show()

# %%
# Plot the classified buildings
fig, ax = plt.subplots(1, 1, figsize=(12, 12))
gdf.plot(column='label', cmap='coolwarm', alpha=0.7, legend=True, ax=ax,
         legend_kwds={'loc': 'lower right', 'title': "Predicted Labels"})

scalebar = ScaleBar(1, location='lower left', pad=1, box_alpha=0.5)
ax.add_artist(scalebar)

# Add north arrow
x, y, arrow_length = 0.04, 1, 0.08
ax.annotate('N', xy=(x, y), xytext=(x, y-arrow_length),
            arrowprops=dict(facecolor='black', headwidth=15, headlength=20, width=5),
            ha='center', va='center', fontsize=15,
            xycoords=ax.transAxes)

# Add resource text
plt.text(0.5, 0.02, 'Data source: OpenStreetMap', horizontalalignment='center',
         verticalalignment='center', transform=ax.transAxes, fontsize=7)

plt.title('Buildings TS Classification using UMMs - Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # BEYOND IS UNDER CONSTRUCTION

# %%
# Merge datasets on unique identifier
merged_df = pd.merge(gdf[['uID', 'predicted_label']], complete_buildings[['uID', 'label']], on='uID')
print(merged_df)

# %%
# Add a new column to indicate whether predictions are correct
merged_df['correct_prediction'] = merged_df['predicted_label'] == merged_df['label']

# Map colors based on correctness: Red for correct, Yellow for incorrect
color_map = merged_df['correct_prediction'].map({True: 'red', False: 'yellow'})

# Merge back with the GeoDataFrame to retain geometries
merged_gdf = gdf.merge(merged_df[['uID', 'correct_prediction']], on='uID', how='left')

# Plot the merged GeoDataFrame
fig, ax = plt.subplots(1, 1, figsize=(12, 12))
merged_gdf.plot(ax=ax, color=color_map, alpha=0.7)

# Add a legend
legend_labels = {
    'red': 'Correct Prediction',
    'yellow': 'Incorrect Prediction'
}
for color, label in legend_labels.items():
    ax.scatter([], [], c=color, label=label)

ax.legend(loc='lower right', title='Prediction Results')

# Add title and other annotations
plt.title('Prediction Accuracy for Buildings')
ax.set_axis_off()
plt.show()

# %%
# Number of correct predictions
correct_predictions = (merged_df['predicted_label'] == merged_df['label']).sum()

# Total number of predictions
total_predictions = len(merged_df)

# Overall accuracy
o_accuracy = correct_predictions / total_predictions

print(f"Overall Accuracy: {o_accuracy * 100:.2f}%")

# %%
# Confusion matrix
conf_matrix = confusion_matrix(merged_df['label_true'], merged_df['label_pred'], labels=['favela', 'not-favela'])

# Plot
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['favela', 'not-favela'], yticklabels=['favela', 'not-favela'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## MAKING PREDICTIONS ON SAME DATA

# %%
import geopandas as gpd
import momepy as mm
import pandas as pd
import numpy as np
from shapely.geometry import Polygon
import warnings

def perform_perfect_tessellation(buildings_path, min_area=1.0, buffer_dist=100, max_iterations=10):
    """
    Performs morphological tessellation ensuring perfect 1:1 matching between buildings and tessellation cells.

    Parameters:
    buildings_path (str): Path to the buildings shapefile
    min_area (float): Minimum area threshold for buildings
    buffer_dist (float): Distance for buffered limit
    max_iterations (int): Maximum number of cleaning iterations to prevent infinite loops

    Returns:
    tuple: (clean_buildings, tessellation, excluded_buildings, report)
    """
    # Initialize report dictionary
    report = {
        'original_count': 0,
        'excluded_count': 0,
        'final_count': 0,
        'iterations_needed': 0,
        'reasons_for_exclusion': {},
        'tessellation_count': 0
    }

    # Read buildings
    buildings = gpd.read_file(buildings_path)
    report['original_count'] = len(buildings)

    # Create a copy for tracking excluded buildings
    excluded_buildings = gpd.GeoDataFrame(columns=buildings.columns + ['exclusion_reason'])

    def is_suitable_geometry(geom):
        if geom is None:
            return False, "null_geometry"
        if not geom.is_valid:
            return False, "invalid_geometry"
        if geom.is_empty:
            return False, "empty_geometry"
        if not isinstance(geom, Polygon):
            return False, "not_polygon"
        if geom.area < min_area:
            return False, "too_small"
        return True, "suitable"

    # Initial geometry cleaning
    clean_buildings = buildings.copy()
    exclusion_mask = pd.Series(False, index=buildings.index)
    reasons = []

    # First pass: remove obviously problematic geometries
    for idx, geom in buildings.geometry.items():
        is_suitable, reason = is_suitable_geometry(geom)
        if not is_suitable:
            exclusion_mask.loc[idx] = True
            reasons.append(reason)
            report['reasons_for_exclusion'][reason] = report['reasons_for_exclusion'].get(reason, 0) + 1

    # Separate initially excluded buildings
    initially_excluded = buildings[exclusion_mask].copy()
    initially_excluded['exclusion_reason'] = reasons
    excluded_buildings = pd.concat([excluded_buildings, initially_excluded])

    # Keep only initially clean buildings
    clean_buildings = buildings[~exclusion_mask].copy()
    clean_buildings = clean_buildings.reset_index(drop=True)

    # Iterative cleaning process
    iteration = 0
    while iteration < max_iterations:
        iteration += 1

        if len(clean_buildings) == 0:
            raise Exception("No clean buildings remaining after filtering")

        try:
            # Assign unique IDs
            clean_buildings['uID'] = mm.unique_id(clean_buildings)

            # Create tessellation
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore', category=UserWarning)
                limit = mm.buffered_limit(clean_buildings, buffer_dist)
                tessellation = mm.morphological_tessellation(clean_buildings, clip=limit)

                # Ensure tessellation index matches building uIDs
                tessellation.index = tessellation.index.astype(int)

                # Check for missing buildings in tessellation
                missing_uids = set(clean_buildings['uID']) - set(tessellation.index)

                # If perfect match achieved, break the loop
                if len(missing_uids) == 0 and len(clean_buildings) == len(tessellation):
                    break

                # If mismatches found, remove problematic buildings
                problem_buildings = clean_buildings[clean_buildings['uID'].isin(missing_uids)].copy()
                problem_buildings['exclusion_reason'] = 'tessellation_failure'
                excluded_buildings = pd.concat([excluded_buildings, problem_buildings])

                # Update clean buildings
                clean_buildings = clean_buildings[~clean_buildings['uID'].isin(missing_uids)].copy()
                clean_buildings = clean_buildings.reset_index(drop=True)

                report['reasons_for_exclusion']['tessellation_failure'] = \
                    report['reasons_for_exclusion'].get('tessellation_failure', 0) + len(problem_buildings)

        except Exception as e:
            raise Exception(f"Error during tessellation iteration {iteration}: {str(e)}")

    # Update final report
    report['iterations_needed'] = iteration
    report['excluded_count'] = len(excluded_buildings)
    report['final_count'] = len(clean_buildings)
    report['tessellation_count'] = len(tessellation)

    # Final validation
    if len(clean_buildings) != len(tessellation):
        raise Exception(f"Failed to achieve perfect matching after {max_iterations} iterations")

    return clean_buildings, tessellation, excluded_buildings, report

def print_perfect_tessellation_report(report):
    """Print a formatted report of the perfect tessellation process"""
    print("\n=== Perfect Tessellation Report ===")
    print(f"\nBuilding Counts:")
    print(f"Original buildings: {report['original_count']}")
    print(f"Excluded buildings: {report['excluded_count']}")
    print(f"Final clean buildings: {report['final_count']}")
    print(f"Tessellation cells: {report['tessellation_count']}")
    print(f"\nIterations needed: {report['iterations_needed']}")

    print("\nReasons for Exclusion:")
    for reason, count in report['reasons_for_exclusion'].items():
        print(f"{reason}: {count} buildings")

    if report['final_count'] == report['tessellation_count']:
        print("\n✓ Perfect 1:1 matching achieved between buildings and tessellation cells")
    else:
        print("\n⚠ Warning: Perfect matching not achieved")

# %%
try:
    buildings_path = r"C:\Users\miles\OneDrive\Desktop\school\UROP\Data\best_test_set.shp" #DATA SOURCE GOES HERE
    clean_buildings, tessellation, excluded_buildings, report = perform_perfect_tessellation(
        buildings_path,
        min_area=1.0,
        buffer_dist=100,
        max_iterations=10
    )

    print_perfect_tessellation_report(report)

    # Save results
    # clean_buildings.to_file("clean_buildings.shp")
    # excluded_buildings.to_file("excluded_buildings.shp")
    # tessellation.to_file("tessellation.shp")

except Exception as e:
    print(f"Error: {str(e)}")

# %%
#Number of buildings obtained for training dataset
print(len(clean_buildings))

# %%
f, ax = plt.subplots(figsize=(10, 10))
tessellation.plot(ax=ax, edgecolor='white', linewidth=0.5, facecolor='blue', alpha=.7)
clean_buildings.plot(ax=ax, color='white', alpha=.7)
plt.title('Tessellation out of OSM building footprints - Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# ## Areas
# Building areas

# %%
# blg_area = mm.Area(buildings)
# buildings['area'] = blg_area.series
clean_buildings["area"] = clean_buildings.area

# %%
f, ax = plt.subplots(figsize=(10, 10))
# Korail.plot(ax=ax, edgecolor='red', facecolor='none', linewidth=2)
clean_buildings.plot(ax=ax, column='area', legend=True, scheme='quantiles', k=15, cmap='magma') # what is scheme = 'quantiles'
plt.title('Building areas Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Perimeters

# %%
# buildings['perimeter'] = mm.Perimeter(buildings).series
# buildings.perimeter[0]

clean_buildings['perimeter'] = clean_buildings.length

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='perimeter', legend=True, scheme='quantiles', k=15, cmap='magma')
plt.title('Building perimeters Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Facade Ratio

# %%
clean_buildings['facade_ratio'] = momepy.facade_ratio(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='facade_ratio', legend=True, scheme='quantiles', cmap='flare')
plt.title('Facade Ratio')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Longest Axis Length

# %% [markdown]
# Calculates the length of the longest axis of object. Axis is defined as a diameter of minimal circumscribed circle around the convex hull

# %%
# buildings['lal'] = mm.LongestAxisLength(buildings).series
# buildings.lal[0]
clean_buildings["lal"] = momepy.longest_axis_length(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='lal', legend=True, scheme='quantiles', cmap='Wistia')
plt.title('Longest Axis Length - Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Shape Index

# %%
clean_buildings['shape_idx'] = momepy.shape_index(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='shape_idx', legend=True, scheme='quantiles', k=15, cmap='Blues')
plt.title('Shape Index')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Compact Weighted Axis

# %%
clean_buildings['compact_weighted_axis'] = momepy.compactness_weighted_axis(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='compact_weighted_axis', legend=True, scheme='quantiles', k=15, cmap='Greens')
plt.title('Compactness Weighted Axis')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Convexity

# %%
clean_buildings['convexity'] = momepy.convexity(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='convexity', legend=True, scheme='quantiles', k=15, cmap='Reds')
plt.title('Convexity')
ax.set_axis_off()
plt.show()

# %% [markdown]
# ## **SPATIAL DISTRIBUTION METRICS**

# %% [markdown]
# # Distance to neighbours buidlings

# %% [markdown]
# Caculates the distance to neighbours buildings through queen contiguity weights of the first order capturing the relationship between immediate neighbours. Relationship between buildings is here represented by relationships between their tessellation cells.

# %%
# contiguity = graph.Graph.build_contiguity(tessellation) #calculated at earlier stage
# contiguity

# %%
clean_buildings["neighbour_dist"] = momepy.neighbor_distance(clean_buildings, queen_tess)
clean_buildings

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='neighbour_dist', scheme='naturalbreaks', k=15, legend=True, cmap='Spectral')
plt.title('Mean distance between buildings Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Mean Interbuilding Distance

# %% [markdown]
#  Interbuilding distances are calculated between buildings on adjacent cells based on spatial_weights,

# %%
# calculated within vicinity defined by the order of contiguity.
# queen_tess alreday calculated at earlier stage; no need to recalculate
# queen_tess = graph.Graph.build_contiguity(tessellation, rook=False)

# neighborhood_graph
dist200 = graph.Graph.build_distance_band(clean_buildings.centroid, 200)

clean_buildings["mean_interbuilding_distance"] = momepy.mean_interbuilding_distance(
    clean_buildings, adjacency_graph=queen_tess, neighborhood_graph=dist200
)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='mean_interbuilding_distance', scheme='naturalbreaks', k=15, legend=True, cmap='Spectral')
plt.title('Mean interbuilding distance - Nova Cidade')
ax.set_axis_off()
plt.show()

# %%
print(clean_buildings.columns)

# %% [markdown]
# # Building Adjaceny

# %%
clean_buildings["adjacency"] = momepy.building_adjacency(
    contiguity_graph=queen_tess, neighborhood_graph=dist200
)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='adjacency', scheme='naturalbreaks', k=15, legend=True, cmap='Spectral')
plt.title('Building Adjacency')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Street Orietation

# %%
# https://docs.momepy.org/en/stable/api/momepy.street_alignment.html#momepy.street_alignment

# %% [markdown]
# ## **SHAPE METRICS**

# %% [markdown]
# # Shared Walls

# %%
clean_buildings['shared_walls'] = momepy.shared_walls(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='shared_walls', scheme='quantiles', legend=True, cmap='Reds')
plt.title('Shared Walls')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Perimeter Wall

# %%
clean_buildings['perimeter_wall'] = momepy.perimeter_wall(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='perimeter_wall', scheme='quantiles', legend=True, cmap='Oranges')
plt.title('Perimeter Wall')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Corners

# %%
clean_buildings['corners'] = momepy.corners(clean_buildings, include_interiors=True)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='corners', scheme='quantiles', legend=True, cmap='Blues')
plt.title('Number of Corners')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Equivalent Rectangular Index

# %%
clean_buildings['rect_idx'] = momepy.equivalent_rectangular_index(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='rect_idx', scheme='quantiles', k = 10, legend=True, cmap='flare')
plt.title('Equivalent Rectangular Index')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Rectangularity

# %%
clean_buildings['rectangularity'] = momepy.rectangularity(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='rectangularity', scheme='quantiles', k = 10, legend=True, cmap='magma')
plt.title('Rectangularity')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Squareness

# %%
clean_buildings['squareness'] = momepy.squareness(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='squareness', scheme='quantiles', k = 10, legend=True, cmap='magma')
plt.title('Squareness')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Square Compactness

# %%
clean_buildings['square_compact'] = momepy.square_compactness(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='square_compact', scheme='quantiles', k = 10, legend=True, cmap='cool')
plt.title('Square Compactness')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Circular compactness

# %% [markdown]
# measures the ratio of object area to the area of its smallest circumsribed circle.
# This ratio indicates how efficiently the object's area fills the smallest circumscribed circle.
# Values closer to 1 indicating a shape more similar to a perfect circle.

# %%
clean_buildings['circular_com'] = momepy.circular_compactness(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='circular_com', scheme='quantiles', legend=True, cmap='viridis')
plt.title('Circular compactness - Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Elongation

# %% [markdown]
# Elongation of its minimum bounding rectangle.
# If the elongation is close to 1, the object is more or less square-shaped indicating little to no elongation.
# If it is much greater than 1, the object is significantly elongated in one direction.

# %%
clean_buildings['elongation'] = momepy.elongation(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='elongation', scheme='quantiles', legend=True, cmap='Blues_r')
plt.title('Elongation of the buildings - Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Cell shapes

# %% [markdown]
# Calculates the compactness-weighted axis of each tessellation

# %%
#FIX
tes_cwa = mm.CompactnessWeightedAxis(tessellation)
tessellation['cwa'] = tes_cwa.series

# %%
f, ax = plt.subplots(figsize=(10, 10))

tessellation.plot(ax=ax, column='cwa', legend=True, scheme='quantiles', k=10, cmap='Greens_r')
plt.title('compactness-weighted axis of each tessellation - Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# ## Covered Area Ratio

# %%
print("Tessellation columns:", tessellation.columns.tolist())
print("Clean buildings columns:", clean_buildings.columns.tolist())

tessellation['area'] = tessellation.geometry.area

# %%
# USING UID

tessellation['uID'] = range(len(tessellation))

# Group buildings by tessellation cell and sum their areas
building_areas = clean_buildings.groupby('uID')['area'].sum()

# Calculate CAR by dividing the summed building areas by tessellation areas
tessellation = tessellation.set_index('uID')
tessellation['CAR'] = building_areas / tessellation['area']
tessellation = tessellation.reset_index()

print(clean_buildings.columns)

# %%
# Group buildings by index and sum their areas
building_areas = clean_buildings.groupby(level=0)['area'].sum()

# Calculate CAR directly using index matching
tessellation['CAR'] = building_areas / tessellation['area']

print(tessellation['CAR'].head())

# %%
f, ax = plt.subplots(figsize=(10, 10))
tessellation.plot(ax=ax, column='CAR', legend=True, scheme='quantiles', k=10, cmap='viridis')
plt.title('Covered Area Ratio Nova Cidade')
clean_buildings.plot(ax=ax, color='white', alpha=0.5)
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Tesselation Area

# %%
tessellation['tes_area'] = tessellation.geometry.area

# %%
f, ax = plt.subplots(figsize=(10, 10))

tessellation.plot(ax=ax, edgecolor='grey', linewidth=0.5, column='tes_area', legend=True, scheme='quantiles', k=10, cmap='magma', alpha=1)
clean_buildings.plot(ax=ax, color='black', alpha=.3)
plt.title('Tesselation Areas Nova Cidade')

ax.set_axis_off()
plt.show()

# %%
print(tessellation.head())

# %% [markdown]
# # Cell Alignment

# %%
blg_orient = momepy.orientation(clean_buildings)
tess_orient = momepy.orientation(tessellation)
clean_buildings['cell_alignment'] = momepy.cell_alignment(blg_orient, tess_orient)

# %%
f, ax = plt.subplots(figsize=(10, 10))

clean_buildings.plot(ax=ax, column='cell_alignment', legend=True, scheme='quantiles', k=10, cmap='Blues')
plt.title('cell alignment')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Tes Neighbors

# %%
tessellation['num_neighbors'] = momepy.neighbors(tessellation, queen_tess)

# %%
f, ax = plt.subplots(figsize=(10, 10))
tessellation.plot(ax=ax, column='num_neighbors', legend=True, scheme='quantiles', k=10, cmap='Blues')
plt.title('Tesselation Num Neighbors')
clean_buildings.plot(ax=ax, color='white', alpha=0.5)
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Fractal dimension

# %% [markdown]
# A fractal dimension greater than 1 for a 2-dimensional patch indicates a departure
# from euclidean geometry (that is, an increase in shape complexity).

# %%
clean_buildings['fractal'] = momepy.fractal_dimension(clean_buildings)
clean_buildings.fractal[0]

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='fractal', legend=True, scheme='quantiles', cmap='Wistia')
plt.title('Fractal dimension - Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # TOPOLOGY METRICS

# %% [markdown]
# # Obtain basic dataset = Centroids of the buildings

# %%
# Centroids of the buildings
def multipolygon_centroid(geom):
    if geom.geom_type == 'MultiPolygon':
        return geom.convex_hull.centroid
    else:
        return geom.centroid

clean_buildings['centroid'] = clean_buildings.geometry.apply(multipolygon_centroid)

# Create a GeoDataFrame for the centroids with uID
centroids_gdf = gpd.GeoDataFrame({
    'uID': clean_buildings['uID'],
    'geometry': clean_buildings['centroid']
}, crs=clean_buildings.crs)

# %%
print(clean_buildings.columns)

# %%
# Plot
f, ax = plt.subplots(figsize=(10, 10))
tessellation.plot(ax=ax, edgecolor='white', linewidth=0.5, facecolor='grey', alpha=.7)
clean_buildings.plot(ax=ax, color='red', alpha=.7)
centroids_gdf.plot(ax=ax, color='black', markersize=0.5, marker='o', label='Centroids')
plt.title('Tessellation out of OSM building footprints + centroids - Nova Cidade')
ax.set_axis_off()
plt.show()

# %%
total_nodes = len(centroids_gdf)
print(f"Total number of nodes: {total_nodes}")
total_buildings = len(clean_buildings)
print(f"Total number of buildings: {total_buildings}")

# %% [markdown]
# # Delaunay Triangulation

# %%
#Coordinates based on the centroids of the buildings
coordinates = np.column_stack((centroids_gdf.geometry.x, centroids_gdf.geometry.y))

from scipy.spatial import Delaunay
tri = Delaunay(coordinates)

# Create a networkx graph out of the Delaunay triangulation
G = nx.Graph()

# Add edges to the graph
for simplex in tri.simplices:
    for i in range(3):
        for j in range(i + 1, 3):
            G.add_edge(simplex[i], simplex[j])

# Get positions of the nodes for plotting
positions = {i: (coordinates[i, 0], coordinates[i, 1]) for i in range(len(coordinates))}

# %%
# Plot
f, ax = plt.subplots(figsize=(10, 10))
tessellation.plot(ax=ax, edgecolor='white', linewidth=0.5, facecolor='grey', alpha=.7)
clean_buildings.plot(ax=ax, color='white', alpha=.7)

# Edges of the Delaunay triangulation
nx.draw(G, pos=positions, node_size=0.1, node_color='red', edge_color='black', width=0.5)
plt.title('Delaunay Triangulation of Nova Cidade buildings')
plt.show()

# %% [markdown]
# # Weighted distance

# %%
# Edges to the graph with weights based on Euclidean distance
for simplex in tri.simplices:
    for i in range(3):
        for j in range(i + 1, 3):
            p1 = coordinates[simplex[i]]
            p2 = coordinates[simplex[j]]
            distance = euclidean(p1, p2) #scipy
            G.add_edge(simplex[i], simplex[j], weight=distance) #networkx

# Extract edges with their weights
edges = []
for u, v, data in G.edges(data=True):
    line = LineString([coordinates[u], coordinates[v]])
    edges.append({'geometry': line, 'weight': data['weight']})

# Geodataframe of edges
gdf_edges = gpd.GeoDataFrame(edges)

# %%
#Plot
f, ax = plt.subplots(figsize=(10, 10))

# centroids_gdf.plot(ax=ax, color='grey', markersize=0.5, marker='o', label='Centroids', zorder=5)

gdf_edges.plot(ax=ax, column='weight', legend=True, scheme='quantiles', k=10, cmap='viridis', linewidth=0.7, zorder=0)

plt.title('Weighted Delaunay Triangulation')
ax.set_axis_off()
plt.show()

# %%
# Initialize a dictionary to store average weighted distances for each node
node_avg_weighted_distance = {}

# Loop through each node in the graph
for node in G.nodes():
    # Get all neighboring nodes (adjacent nodes)
    neighbors = list(G.neighbors(node))

    # Calculate average weighted distance
    total_weighted_distance = 0.0
    count = 0

    # Iterate over edges connecting the node to its neighbors
    for neighbor in neighbors:
        # Get the weight of the edge between node and neighbor
        weight = G[node][neighbor]['weight']

        # Accumulate weighted distance
        total_weighted_distance += weight
        count += 1

    # Calculate average weighted distance for the node
    if count > 0:
        avg_weighted_distance = total_weighted_distance / count
    else:
        avg_weighted_distance = 0.0

    # Store the average weighted distance in the dictionary
    node_avg_weighted_distance[node] = avg_weighted_distance

# Print or use node_avg_weighted_distance as needed
print(node_avg_weighted_distance)

# %%
# Ensure that the GeoDataFrame indices match the graph nodes
centroids_gdf = centroids_gdf.reset_index(drop=True)

# Ensure centroids_gdf has uID as index
# centroids_gdf.set_index('uID', inplace=True)

# Map the average weighted distances to the GeoDataFrame
centroids_gdf['avg_weighted_distance'] = centroids_gdf.index.map(node_avg_weighted_distance)

# Verify the mapping
print(centroids_gdf[['avg_weighted_distance']].head())

# Plot to visualize the average weighted distances
f, ax = plt.subplots(figsize=(10, 10))

# Ensure avg_weighted_distance column exists and is not empty
if 'avg_weighted_distance' in centroids_gdf.columns and not centroids_gdf['avg_weighted_distance'].isnull().all():
    centroids_gdf.plot(ax=ax, column='avg_weighted_distance',  legend=True, scheme='quantiles', cmap='viridis', markersize=5, linewidth=0.5, zorder=5)
    gdf_edges.plot(ax=ax, color='grey', linewidth=0.3, zorder=0)
    plt.title('Average Weighted Distance of Building Centroids')
    ax.set_axis_off()
    plt.show()
else:
    print("Average weighted distance data is missing or empty.")

# %%
total_nodes = len(centroids_gdf)
print(f"Total number of nodes: {total_nodes}")
print(len(clean_buildings))
#same amount of nodes to buildings :)

# %%
# blg_area = mm.Area(buildings)
# buildings['area'] = blg_area.series
clean_buildings["area"] = clean_buildings.area

# %%
f, ax = plt.subplots(figsize=(10, 10))
# Korail.plot(ax=ax, edgecolor='red', facecolor='none', linewidth=2)
clean_buildings.plot(ax=ax, column='area', legend=True, scheme='quantiles', k=15, cmap='magma') # what is scheme = 'quantiles'
plt.title('Building areas Nova Cidade')
ax.set_axis_off()
plt.show()

# %%
# buildings['perimeter'] = mm.Perimeter(buildings).series
# buildings.perimeter[0]

clean_buildings['perimeter'] = clean_buildings.length

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='perimeter', legend=True, scheme='quantiles', k=15, cmap='magma')
plt.title('Building perimeters Nova Cidade')
ax.set_axis_off()
plt.show()

# %%
clean_buildings['facade_ratio'] = momepy.facade_ratio(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='facade_ratio', legend=True, scheme='quantiles', cmap='flare')
plt.title('Facade Ratio')
ax.set_axis_off()
plt.show()

# %% [markdown]
# Calculates the length of the longest axis of object. Axis is defined as a diameter of minimal circumscribed circle around the convex hull

# %%
# buildings['lal'] = mm.LongestAxisLength(buildings).series
# buildings.lal[0]
clean_buildings["lal"] = momepy.longest_axis_length(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='lal', legend=True, scheme='quantiles', cmap='Wistia')
plt.title('Longest Axis Length - Nova Cidade')
ax.set_axis_off()
plt.show()

# %%
clean_buildings['shape_idx'] = momepy.shape_index(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='shape_idx', legend=True, scheme='quantiles', k=15, cmap='Blues')
plt.title('Shape Index')
ax.set_axis_off()
plt.show()

# %%
clean_buildings['compact_weighted_axis'] = momepy.compactness_weighted_axis(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='compact_weighted_axis', legend=True, scheme='quantiles', k=15, cmap='Greens')
plt.title('Compactness Weighted Axis')
ax.set_axis_off()
plt.show()

# %%
clean_buildings['convexity'] = momepy.convexity(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='convexity', legend=True, scheme='quantiles', k=15, cmap='Reds')
plt.title('Convexity')
ax.set_axis_off()
plt.show()

# %% [markdown]
# ## **SPATIAL DISTRIBUTION METRICS**

# %% [markdown]
# Caculates the distance to neighbours buildings through queen contiguity weights of the first order capturing the relationship between immediate neighbours. Relationship between buildings is here represented by relationships between their tessellation cells.

# %%
contiguity = graph.Graph.build_contiguity(tessellation)
contiguity

# %%
clean_buildings["neighbour_dist"] = momepy.neighbor_distance(clean_buildings, contiguity)
clean_buildings

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='neighbour_dist', scheme='naturalbreaks', k=15, legend=True, cmap='Spectral')
plt.title('Mean distance between buildings Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
#  Interbuilding distances are calculated between buildings on adjacent cells based on spatial_weights,

# %%
# MID = mm.MeanInterbuildingDistance(buildings, sw1,'uID')
# buildings['mean_interbuilding_distance'] = MID.series

# calculated within vicinity defined by the order of contiguity.
queen_tess = graph.Graph.build_contiguity(tessellation, rook=False)

# neighborhood_graph
dist200 = graph.Graph.build_distance_band(clean_buildings.centroid, 200)

clean_buildings["mean_interbuilding_distance"] = momepy.mean_interbuilding_distance(
    clean_buildings, adjacency_graph=queen_tess, neighborhood_graph=dist200
)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='mean_interbuilding_distance', scheme='naturalbreaks', k=15, legend=True, cmap='Spectral')
plt.title('Mean interbuilding distance - Nova Cidade')
ax.set_axis_off()
plt.show()

# %%
print(clean_buildings.columns)

# %%
clean_buildings["adjacency"] = momepy.building_adjacency(
    contiguity_graph=queen_tess, neighborhood_graph=dist200
)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='adjacency', scheme='naturalbreaks', k=15, legend=True, cmap='Spectral')
plt.title('Building Adjacency')
ax.set_axis_off()
plt.show()

# %%
# https://docs.momepy.org/en/stable/api/momepy.street_alignment.html#momepy.street_alignment

# %% [markdown]
# ## **SHAPE METRICS**

# %%
clean_buildings['perimeter_wall'] = momepy.perimeter_wall(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='perimeter_wall', scheme='quantiles', legend=True, cmap='Oranges')
plt.title('Perimeter Wall')
ax.set_axis_off()
plt.show()

# %%
clean_buildings['corners'] = momepy.corners(clean_buildings, include_interiors=True)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='corners', scheme='quantiles', legend=True, cmap='Blues')
plt.title('Number of Corners')
ax.set_axis_off()
plt.show()

# %%
clean_buildings['rect_idx'] = momepy.equivalent_rectangular_index(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='rect_idx', scheme='quantiles', k = 10, legend=True, cmap='flare')
plt.title('Equivalent Rectangular Index')
ax.set_axis_off()
plt.show()

# %%
clean_buildings['rectangularity'] = momepy.rectangularity(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='rectangularity', scheme='quantiles', k = 10, legend=True, cmap='magma')
plt.title('Rectangularity')
ax.set_axis_off()
plt.show()

# %%
clean_buildings['squareness'] = momepy.squareness(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='squareness', scheme='quantiles', k = 10, legend=True, cmap='magma')
plt.title('Squareness')
ax.set_axis_off()
plt.show()

# %%
clean_buildings['square_compact'] = momepy.square_compactness(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='square_compact', scheme='quantiles', k = 10, legend=True, cmap='cool')
plt.title('Square Compactness')
ax.set_axis_off()
plt.show()

# %% [markdown]
# measures the ratio of object area to the area of its smallest circumsribed circle.
# This ratio indicates how efficiently the object's area fills the smallest circumscribed circle.
# Values closer to 1 indicating a shape more similar to a perfect circle.

# %%
clean_buildings['circular_com'] = momepy.circular_compactness(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='circular_com', scheme='quantiles', legend=True, cmap='viridis')
plt.title('Circular compactness - Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# Elongation of its minimum bounding rectangle.
# If the elongation is close to 1, the object is more or less square-shaped indicating little to no elongation.
# If it is much greater than 1, the object is significantly elongated in one direction.

# %%
clean_buildings['elongation'] = momepy.elongation(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='elongation', scheme='quantiles', legend=True, cmap='Blues_r')
plt.title('Elongation of the buildings - Nova Cidade')
ax.set_axis_off()
plt.show()

# %%
print("Tessellation columns:", tessellation.columns.tolist())
print("Clean buildings columns:", clean_buildings.columns.tolist())

tessellation['area'] = tessellation.geometry.area

# %%
# USING UID

tessellation['uID'] = range(len(tessellation))

# Group buildings by tessellation cell and sum their areas
building_areas = clean_buildings.groupby('uID')['area'].sum()

# Calculate CAR by dividing the summed building areas by tessellation areas
tessellation = tessellation.set_index('uID')
tessellation['CAR'] = building_areas / tessellation['area']
tessellation = tessellation.reset_index()

print(clean_buildings.columns)

# %%
# Group buildings by index and sum their areas
building_areas = clean_buildings.groupby(level=0)['area'].sum()

# Calculate CAR directly using index matching
tessellation['CAR'] = building_areas / tessellation['area']

print(tessellation['CAR'].head())

# %%
f, ax = plt.subplots(figsize=(10, 10))
tessellation.plot(ax=ax, column='CAR', legend=True, scheme='quantiles', k=10, cmap='viridis')
plt.title('Covered Area Ratio Nova Cidade')
clean_buildings.plot(ax=ax, color='white', alpha=0.5)
ax.set_axis_off()
plt.show()

# %%
tessellation['tes_area'] = tessellation.geometry.area

# %%
f, ax = plt.subplots(figsize=(10, 10))

tessellation.plot(ax=ax, edgecolor='grey', linewidth=0.5, column='tes_area', legend=True, scheme='quantiles', k=10, cmap='magma', alpha=1)
clean_buildings.plot(ax=ax, color='black', alpha=.3)
plt.title('Tesselation Areas Nova Cidade')

ax.set_axis_off()
plt.show()

# %%
print(tessellation.head())

# %%
blg_orient = momepy.orientation(clean_buildings)
tess_orient = momepy.orientation(tessellation)
clean_buildings['cell_alignment'] = momepy.cell_alignment(blg_orient, tess_orient)

# %%
f, ax = plt.subplots(figsize=(10, 10))

clean_buildings.plot(ax=ax, column='cell_alignment', legend=True, scheme='quantiles', k=10, cmap='Blues')
plt.title('cell alignment')
ax.set_axis_off()
plt.show()

# %%
tessellation['num_neighbors'] = momepy.neighbors(tessellation, queen_tess)

# %%
f, ax = plt.subplots(figsize=(10, 10))
tessellation.plot(ax=ax, column='num_neighbors', legend=True, scheme='quantiles', k=10, cmap='Blues')
plt.title('Tesselation Num Neighbors')
clean_buildings.plot(ax=ax, color='white', alpha=0.5)
ax.set_axis_off()
plt.show()

# %% [markdown]
# A fractal dimension greater than 1 for a 2-dimensional patch indicates a departure
# from euclidean geometry (that is, an increase in shape complexity).

# %%
clean_buildings['fractal'] = momepy.fractal_dimension(clean_buildings)
clean_buildings.fractal[0]

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='fractal', legend=True, scheme='quantiles', cmap='Wistia')
plt.title('Fractal dimension - Nova Cidade')
ax.set_axis_off()
plt.show()

# %%
# Centroids of the buildings
def multipolygon_centroid(geom):
    if geom.geom_type == 'MultiPolygon':
        return geom.convex_hull.centroid
    else:
        return geom.centroid

clean_buildings['centroid'] = clean_buildings.geometry.apply(multipolygon_centroid)

# Create a GeoDataFrame for the centroids with uID
centroids_gdf = gpd.GeoDataFrame({
    'uID': clean_buildings['uID'],
    'geometry': clean_buildings['centroid']
}, crs=clean_buildings.crs)

# %%
print(clean_buildings.columns)

# %%
# Plot
f, ax = plt.subplots(figsize=(10, 10))
tessellation.plot(ax=ax, edgecolor='white', linewidth=0.5, facecolor='grey', alpha=.7)
clean_buildings.plot(ax=ax, color='red', alpha=.7)
centroids_gdf.plot(ax=ax, color='black', markersize=0.5, marker='o', label='Centroids')
plt.title('Tessellation out of OSM building footprints + centroids - Nova Cidade')
ax.set_axis_off()
plt.show()

# %%
total_nodes = len(centroids_gdf)
print(f"Total number of nodes: {total_nodes}")
total_buildings = len(clean_buildings)
print(f"Total number of buildings: {total_buildings}")

# %%
#Coordinates based on the centroids of the buildings
coordinates = np.column_stack((centroids_gdf.geometry.x, centroids_gdf.geometry.y))

from scipy.spatial import Delaunay
tri = Delaunay(coordinates)

# Create a networkx graph out of the Delaunay triangulation
G = nx.Graph()

# Add edges to the graph
for simplex in tri.simplices:
    for i in range(3):
        for j in range(i + 1, 3):
            G.add_edge(simplex[i], simplex[j])

# Get positions of the nodes for plotting
positions = {i: (coordinates[i, 0], coordinates[i, 1]) for i in range(len(coordinates))}

# %%
# Plot
f, ax = plt.subplots(figsize=(10, 10))
tessellation.plot(ax=ax, edgecolor='white', linewidth=0.5, facecolor='grey', alpha=.7)
clean_buildings.plot(ax=ax, color='white', alpha=.7)

# Edges of the Delaunay triangulation
nx.draw(G, pos=positions, node_size=0.1, node_color='red', edge_color='black', width=0.5)
plt.title('Delaunay Triangulation of Nova Cidade buildings')
plt.show()

# %%
# Edges to the graph with weights based on Euclidean distance
for simplex in tri.simplices:
    for i in range(3):
        for j in range(i + 1, 3):
            p1 = coordinates[simplex[i]]
            p2 = coordinates[simplex[j]]
            distance = euclidean(p1, p2) #scipy
            G.add_edge(simplex[i], simplex[j], weight=distance) #networkx

# Extract edges with their weights
edges = []
for u, v, data in G.edges(data=True):
    line = LineString([coordinates[u], coordinates[v]])
    edges.append({'geometry': line, 'weight': data['weight']})

# Geodataframe of edges
gdf_edges = gpd.GeoDataFrame(edges)

# %%
#Plot
f, ax = plt.subplots(figsize=(10, 10))

# centroids_gdf.plot(ax=ax, color='grey', markersize=0.5, marker='o', label='Centroids', zorder=5)

gdf_edges.plot(ax=ax, column='weight', legend=True, scheme='quantiles', k=10, cmap='viridis', linewidth=0.7, zorder=0)

plt.title('Weighted Delaunay Triangulation')
ax.set_axis_off()
plt.show()

# %%
# Initialize a dictionary to store average weighted distances for each node
node_avg_weighted_distance = {}

# Loop through each node in the graph
for node in G.nodes():
    # Get all neighboring nodes (adjacent nodes)
    neighbors = list(G.neighbors(node))

    # Calculate average weighted distance
    total_weighted_distance = 0.0
    count = 0

    # Iterate over edges connecting the node to its neighbors
    for neighbor in neighbors:
        # Get the weight of the edge between node and neighbor
        weight = G[node][neighbor]['weight']

        # Accumulate weighted distance
        total_weighted_distance += weight
        count += 1

    # Calculate average weighted distance for the node
    if count > 0:
        avg_weighted_distance = total_weighted_distance / count
    else:
        avg_weighted_distance = 0.0

    # Store the average weighted distance in the dictionary
    node_avg_weighted_distance[node] = avg_weighted_distance

# Print or use node_avg_weighted_distance as needed
print(node_avg_weighted_distance)

# %%
# Ensure that the GeoDataFrame indices match the graph nodes
centroids_gdf = centroids_gdf.reset_index(drop=True)

# Ensure centroids_gdf has uID as index
# centroids_gdf.set_index('uID', inplace=True)

# Map the average weighted distances to the GeoDataFrame
centroids_gdf['avg_weighted_distance'] = centroids_gdf.index.map(node_avg_weighted_distance)

# Verify the mapping
print(centroids_gdf[['avg_weighted_distance']].head())

# Plot to visualize the average weighted distances
f, ax = plt.subplots(figsize=(10, 10))

# Ensure avg_weighted_distance column exists and is not empty
if 'avg_weighted_distance' in centroids_gdf.columns and not centroids_gdf['avg_weighted_distance'].isnull().all():
    centroids_gdf.plot(ax=ax, column='avg_weighted_distance',  legend=True, scheme='quantiles', cmap='viridis', markersize=5, linewidth=0.5, zorder=5)
    gdf_edges.plot(ax=ax, color='grey', linewidth=0.3, zorder=0)
    plt.title('Average Weighted Distance of Building Centroids')
    ax.set_axis_off()
    plt.show()
else:
    print("Average weighted distance data is missing or empty.")

# %%
total_nodes = len(centroids_gdf)
print(f"Total number of nodes: {total_nodes}")
print(len(clean_buildings))
#same amount of nodes to buildings :)

# %%
print(clean_buildings.columns)

# %% [markdown]
# # Spatial Joint MM and TP

# %%
# Spatial join using geopandas.sjoin
# Merge buildings and centroids_gdf, ensuring we retain the geometry column
# Step 1: Merge clean_buildings with centroids_gdf on uID
buildings_with_centroids = clean_buildings.merge(
    centroids_gdf,
    on='uID',
    how='left',
    suffixes=('_building', '_centroid')
)

# Step 2: Merge the result with tessellation using uID
complete_buildings = buildings_with_centroids.merge(
    tessellation,
    on='uID',
    how='left',
    suffixes=('', '_tessellation')
)

# Step 3: Ensure the geometry column is preserved (or reset if overwritten)
complete_buildings = gpd.GeoDataFrame(
    complete_buildings,
    geometry='geometry_building',  # Replace 'geometry_building' with the correct geometry column if needed
    crs=clean_buildings.crs
)

# Step 4: Validate the resulting GeoDataFrame
print(complete_buildings.head())  # Check the joined result
print(complete_buildings.columns)  # Ensure all expected columns are present

joined_gdf = clean_buildings.join(
    centroids_gdf,
    how='left',
    lsuffix='_building',
    rsuffix='_centroid'
)


# Merge the result with the tessellation DataFrame
# joined_gdf = joined_gdf.merge(tessellation, on='uID', how='left', suffixes=('', '_tessellation'))
# joined_gdf = joined_gdf.merge(tessellation, how='left', suffixes=('', '_tessellation'))

joined_gdf = joined_gdf.join(tessellation, how='left', lsuffix='', rsuffix='_tessellation')

# Check the first few rows to verify the join
print(joined_gdf.head())
# print(joined_gdf.geom_type)

# %% [markdown]
# # GROUND TRUTH DATA

# %%
def classify_and_analyze_favelas(clean_buildings, type_column='tipo', plot=True):
    """
    Classify buildings as favela/not-favela and provide analysis.

    Parameters:
    buildings_gdf (GeoDataFrame): Buildings data
    type_column (str): Name of column containing building type codes
    plot (bool): Whether to create visualization

    Returns:
    GeoDataFrame: Buildings with added classification
    dict: Analysis results
    """
    # Create a copy to avoid modifying original
    buildings_copy = clean_buildings.copy()

    # Add classification - check if type_column contains any number
    buildings_copy['label'] = np.where(
        buildings_copy[type_column].notna(), # Check if there's any value
        'favela',
        'not-favela'
    )

    # Calculate statistics
    stats = {
        'total_buildings': len(buildings_copy),
        'favela_count': (buildings_copy['label'] == 'favela').sum(),
        'non_favela_count': (buildings_copy['label'] == 'not-favela').sum(),
        'unique_types': buildings_copy[type_column].unique().tolist(),
        'type_counts': buildings_copy[type_column].value_counts().to_dict()
    }

    stats['favela_percentage'] = (stats['favela_count'] / stats['total_buildings']) * 100

    # Print analysis
    print("\n=== Favela Classification Analysis ===")
    print(f"Total buildings: {stats['total_buildings']}")
    print(f"Favela buildings: {stats['favela_count']} ({stats['favela_percentage']:.1f}%)")
    print(f"Non-favela buildings: {stats['non_favela_count']}")

    print("\nBuilding type distribution:")
    for type_code, count in stats['type_counts'].items():
        print(f"{type_code}: {count} buildings")

    if plot:
        # Create visualization
        f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))

        # Plot 1: Spatial distribution
        buildings_copy.plot(ax=ax1, column='label', categorical=True,
                          legend=True, cmap='Set3',
                          legend_kwds={'title': 'Classification'})
        ax1.set_title('Spatial Distribution of Favelas')
        ax1.set_axis_off()

        # Plot 2: Classification counts
        pd.Series([stats['favela_count'], stats['non_favela_count']],
                  index=['favela', 'not-favela']).plot(kind='bar', ax=ax2,
                  color=['#FF6347', '#4682B4'])
        ax2.set_title('Favela vs Non-Favela Count')
        ax2.set_xlabel('Building Type')
        ax2.set_ylabel('Count')
        plt.xticks(rotation=0)

        plt.tight_layout()
        plt.show()

    return buildings_copy, stats

# %%
try:
    classified_buildings, analysis = classify_and_analyze_favelas(
        complete_buildings,
        type_column='nome_count'
    )
    ground_truth_gdf = classified_buildings

    # Now you can merge with buildings if needed
    complete_buildings['label'] = classified_buildings['label']

    plt.show()

except Exception as e:
    print(f"Error during classification analysis: {str(e)}")

# %%
print("Buildings with labels:")
print(ground_truth_gdf.head())

# %%
# blg_area = mm.Area(buildings)
# buildings['area'] = blg_area.series
clean_buildings["area"] = clean_buildings.area

# %%
f, ax = plt.subplots(figsize=(10, 10))
# Korail.plot(ax=ax, edgecolor='red', facecolor='none', linewidth=2)
clean_buildings.plot(ax=ax, column='area', legend=True, scheme='quantiles', k=15, cmap='magma') # what is scheme = 'quantiles'
plt.title('Building areas Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Classification based on metrics with a stepwise searching between defined ranges

# %%
print(ground_truth_gdf.columns)

# %%
from sklearn.metrics import accuracy_score, classification_report

new_gdf = ground_truth_gdf

# Select features for prediction
X_new = new_gdf[metrics]

# Impute missing values in the new GeoDataFrame using the trained imputer
X_new_imputed = pd.DataFrame(imputer.transform(X_new), columns=X_new.columns)

# Predict using the trained model
new_gdf['predicted_labels'] = rf_model.predict(X_new_imputed)

# Evaluate the predictions if true labels are available
if 'label' in new_gdf:
    y_true_new = new_gdf['label']
    y_pred_new = new_gdf['predicted_labels']

    # Calculate accuracy
    accuracy_new = accuracy_score(y_true_new, y_pred_new) * 100
    print(f"Prediction Accuracy on New Data: {accuracy_new:.2f}%")

    # Generate classification report
    print("Classification Report for New Data:")
    print(classification_report(y_true_new, y_pred_new))

# Plot the predictions
fig, ax = plt.subplots(1, 1, figsize=(12, 12))
new_gdf.plot(column='predicted_labels', cmap='coolwarm', alpha=0.7, legend=True, ax=ax,
             legend_kwds={'loc': 'lower right', 'title': "Predicted Labels"})

# Add scale bar
scalebar = ScaleBar(1, location='lower left', pad=1, box_alpha=0.5)
ax.add_artist(scalebar)

# Add north arrow
x, y, arrow_length = 0.04, 1, 0.08
ax.annotate('N', xy=(x, y), xytext=(x, y-arrow_length),
            arrowprops=dict(facecolor='black', headwidth=15, headlength=20, width=5),
            ha='center', va='center', fontsize=15,
            xycoords=ax.transAxes)

# Add data source text
plt.text(0.5, 0.02, 'Data source: OpenStreetMap', horizontalalignment='center',
         verticalalignment='center', transform=ax.transAxes, fontsize=7)

plt.title('Buildings TS Classification on New Data')
ax.set_axis_off()
plt.show()

# %%
# Evaluate predictions and create a column for correct/incorrect predictions
if 'label' in new_gdf:
    new_gdf['prediction_correct'] = new_gdf['predicted_labels'] == new_gdf['label']

# Plot the predictions
fig, ax = plt.subplots(1, 1, figsize=(12, 12))

# Plot correct predictions in red
new_gdf[new_gdf['prediction_correct']].plot(
    ax=ax, color='red', label='Correct Predictions', alpha=0.7
)

# Plot incorrect predictions in yellow
new_gdf[~new_gdf['prediction_correct']].plot(
    ax=ax, color='yellow', label='Incorrect Predictions', alpha=0.7
)

# Add scale bar
scalebar = ScaleBar(1, location='lower left', pad=1, box_alpha=0.5)
ax.add_artist(scalebar)

# Add north arrow
x, y, arrow_length = 0.04, 1, 0.08
ax.annotate('N', xy=(x, y), xytext=(x, y-arrow_length),
            arrowprops=dict(facecolor='black', headwidth=15, headlength=20, width=5),
            ha='center', va='center', fontsize=15,
            xycoords=ax.transAxes)

# Add legend and title
ax.legend(loc='upper right')
plt.title('Prediction Accuracy Map')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Again!

# %%
import geopandas as gpd
import momepy as mm
import pandas as pd
import numpy as np
from shapely.geometry import Polygon
import warnings

def perform_perfect_tessellation(buildings_path, min_area=1.0, buffer_dist=100, max_iterations=10):
    """
    Performs morphological tessellation ensuring perfect 1:1 matching between buildings and tessellation cells.

    Parameters:
    buildings_path (str): Path to the buildings shapefile
    min_area (float): Minimum area threshold for buildings
    buffer_dist (float): Distance for buffered limit
    max_iterations (int): Maximum number of cleaning iterations to prevent infinite loops

    Returns:
    tuple: (clean_buildings, tessellation, excluded_buildings, report)
    """
    # Initialize report dictionary
    report = {
        'original_count': 0,
        'excluded_count': 0,
        'final_count': 0,
        'iterations_needed': 0,
        'reasons_for_exclusion': {},
        'tessellation_count': 0
    }

    # Read buildings
    buildings = gpd.read_file(buildings_path)
    report['original_count'] = len(buildings)

    # Create a copy for tracking excluded buildings
    excluded_buildings = gpd.GeoDataFrame(columns=buildings.columns + ['exclusion_reason'])

    def is_suitable_geometry(geom):
        if geom is None:
            return False, "null_geometry"
        if not geom.is_valid:
            return False, "invalid_geometry"
        if geom.is_empty:
            return False, "empty_geometry"
        if not isinstance(geom, Polygon):
            return False, "not_polygon"
        if geom.area < min_area:
            return False, "too_small"
        return True, "suitable"

    # Initial geometry cleaning
    clean_buildings = buildings.copy()
    exclusion_mask = pd.Series(False, index=buildings.index)
    reasons = []

    # First pass: remove obviously problematic geometries
    for idx, geom in buildings.geometry.items():
        is_suitable, reason = is_suitable_geometry(geom)
        if not is_suitable:
            exclusion_mask.loc[idx] = True
            reasons.append(reason)
            report['reasons_for_exclusion'][reason] = report['reasons_for_exclusion'].get(reason, 0) + 1

    # Separate initially excluded buildings
    initially_excluded = buildings[exclusion_mask].copy()
    initially_excluded['exclusion_reason'] = reasons
    excluded_buildings = pd.concat([excluded_buildings, initially_excluded])

    # Keep only initially clean buildings
    clean_buildings = buildings[~exclusion_mask].copy()
    clean_buildings = clean_buildings.reset_index(drop=True)

    # Iterative cleaning process
    iteration = 0
    while iteration < max_iterations:
        iteration += 1

        if len(clean_buildings) == 0:
            raise Exception("No clean buildings remaining after filtering")

        try:
            # Assign unique IDs
            clean_buildings['uID'] = mm.unique_id(clean_buildings)

            # Create tessellation
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore', category=UserWarning)
                limit = mm.buffered_limit(clean_buildings, buffer_dist)
                tessellation = mm.morphological_tessellation(clean_buildings, clip=limit)

                # Ensure tessellation index matches building uIDs
                tessellation.index = tessellation.index.astype(int)

                # Check for missing buildings in tessellation
                missing_uids = set(clean_buildings['uID']) - set(tessellation.index)

                # If perfect match achieved, break the loop
                if len(missing_uids) == 0 and len(clean_buildings) == len(tessellation):
                    break

                # If mismatches found, remove problematic buildings
                problem_buildings = clean_buildings[clean_buildings['uID'].isin(missing_uids)].copy()
                problem_buildings['exclusion_reason'] = 'tessellation_failure'
                excluded_buildings = pd.concat([excluded_buildings, problem_buildings])

                # Update clean buildings
                clean_buildings = clean_buildings[~clean_buildings['uID'].isin(missing_uids)].copy()
                clean_buildings = clean_buildings.reset_index(drop=True)

                report['reasons_for_exclusion']['tessellation_failure'] = \
                    report['reasons_for_exclusion'].get('tessellation_failure', 0) + len(problem_buildings)

        except Exception as e:
            raise Exception(f"Error during tessellation iteration {iteration}: {str(e)}")

    # Update final report
    report['iterations_needed'] = iteration
    report['excluded_count'] = len(excluded_buildings)
    report['final_count'] = len(clean_buildings)
    report['tessellation_count'] = len(tessellation)

    # Final validation
    if len(clean_buildings) != len(tessellation):
        raise Exception(f"Failed to achieve perfect matching after {max_iterations} iterations")

    return clean_buildings, tessellation, excluded_buildings, report

def print_perfect_tessellation_report(report):
    """Print a formatted report of the perfect tessellation process"""
    print("\n=== Perfect Tessellation Report ===")
    print(f"\nBuilding Counts:")
    print(f"Original buildings: {report['original_count']}")
    print(f"Excluded buildings: {report['excluded_count']}")
    print(f"Final clean buildings: {report['final_count']}")
    print(f"Tessellation cells: {report['tessellation_count']}")
    print(f"\nIterations needed: {report['iterations_needed']}")

    print("\nReasons for Exclusion:")
    for reason, count in report['reasons_for_exclusion'].items():
        print(f"{reason}: {count} buildings")

    if report['final_count'] == report['tessellation_count']:
        print("\n✓ Perfect 1:1 matching achieved between buildings and tessellation cells")
    else:
        print("\n⚠ Warning: Perfect matching not achieved")

# %%
try:
    buildings_path = r"C:\Users\miles\OneDrive\Desktop\school\UROP\Data\Test Data\Specific Sites\morro-pavao.shp" #DATA SOURCE GOES HERE
    clean_buildings, tessellation, excluded_buildings, report = perform_perfect_tessellation(
        buildings_path,
        min_area=1.0,
        buffer_dist=100,
        max_iterations=10
    )

    print_perfect_tessellation_report(report)

    # Save results
    # clean_buildings.to_file("clean_buildings.shp")
    # excluded_buildings.to_file("excluded_buildings.shp")
    # tessellation.to_file("tessellation.shp")

except Exception as e:
    print(f"Error: {str(e)}")

# %%
#Number of buildings obtained for training dataset
print(len(clean_buildings))

# %%
f, ax = plt.subplots(figsize=(10, 10))
tessellation.plot(ax=ax, edgecolor='white', linewidth=0.5, facecolor='blue', alpha=.7)
clean_buildings.plot(ax=ax, color='white', alpha=.7)
plt.title('Tessellation out of OSM building footprints - Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# ## Areas
# Building areas

# %%
# blg_area = mm.Area(buildings)
# buildings['area'] = blg_area.series
clean_buildings["area"] = clean_buildings.area

# %%
f, ax = plt.subplots(figsize=(10, 10))
# Korail.plot(ax=ax, edgecolor='red', facecolor='none', linewidth=2)
clean_buildings.plot(ax=ax, column='area', legend=True, scheme='quantiles', k=15, cmap='magma') # what is scheme = 'quantiles'
plt.title('Building areas Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Perimeters

# %%
# buildings['perimeter'] = mm.Perimeter(buildings).series
# buildings.perimeter[0]

clean_buildings['perimeter'] = clean_buildings.length

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='perimeter', legend=True, scheme='quantiles', k=15, cmap='magma')
plt.title('Building perimeters Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Longest Axis Length

# %% [markdown]
# Calculates the length of the longest axis of object. Axis is defined as a diameter of minimal circumscribed circle around the convex hull

# %%
# buildings['lal'] = mm.LongestAxisLength(buildings).series
# buildings.lal[0]
clean_buildings["lal"] = momepy.longest_axis_length(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='lal', legend=True, scheme='quantiles', cmap='Wistia')
plt.title('Longest Axis Length - Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# ## **SPATIAL DISTRIBUTION METRICS**

# %% [markdown]
# # Distance to neighbours buidlings

# %% [markdown]
# Caculates the distance to neighbours buildings through queen contiguity weights of the first order capturing the relationship between immediate neighbours. Relationship between buildings is here represented by relationships between their tessellation cells.

# %%
contiguity = graph.Graph.build_contiguity(tessellation)
contiguity

# %%
clean_buildings["neighbour_dist"] = momepy.neighbor_distance(clean_buildings, contiguity)
clean_buildings

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='neighbour_dist', scheme='naturalbreaks', k=15, legend=True, cmap='Spectral')
plt.title('Mean distance between buildings Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Building Adjaceny

# %%
# https://docs.momepy.org/en/stable/user_guide/weights/two.html
# uses the calculation from above

# %% [markdown]
# # Mean Interbuilding Distance

# %% [markdown]
#  Interbuilding distances are calculated between buildings on adjacent cells based on spatial_weights,

# %%
# MID = mm.MeanInterbuildingDistance(buildings, sw1,'uID')
# buildings['mean_interbuilding_distance'] = MID.series

# calculated within vicinity defined by the order of contiguity.
queen_tess = graph.Graph.build_contiguity(tessellation, rook=False)

# neighborhood_graph
dist200 = graph.Graph.build_distance_band(clean_buildings.centroid, 200)

clean_buildings["mean_interbuilding_distance"] = momepy.mean_interbuilding_distance(
    clean_buildings, adjacency_graph=queen_tess, neighborhood_graph=dist200
)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='mean_interbuilding_distance', scheme='naturalbreaks', k=15, legend=True, cmap='Spectral')
plt.title('Mean interbuilding distance - Nova Cidade')
ax.set_axis_off()
plt.show()

# %%
print(clean_buildings.columns)

# %% [markdown]
# ## **SHAPE METRICS**

# %% [markdown]
# # Circular compactness

# %% [markdown]
# measures the ratio of object area to the area of its smallest circumsribed circle.
# This ratio indicates how efficiently the object's area fills the smallest circumscribed circle.
# Values closer to 1 indicating a shape more similar to a perfect circle.

# %%
clean_buildings['circular_com'] = momepy.circular_compactness(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='circular_com', scheme='quantiles', legend=True, cmap='viridis')
plt.title('Circular compactness - Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Elongation

# %% [markdown]
# Elongation of its minimum bounding rectangle.
# If the elongation is close to 1, the object is more or less square-shaped indicating little to no elongation.
# If it is much greater than 1, the object is significantly elongated in one direction.

# %%
clean_buildings['elongation'] = momepy.elongation(clean_buildings)

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='elongation', scheme='quantiles', legend=True, cmap='Blues_r')
plt.title('Elongation of the buildings - Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Cell shapes

# %% [markdown]
# Calculates the compactness-weighted axis of each tessellation

# %%
#FIX
tes_cwa = mm.CompactnessWeightedAxis(tessellation)
tessellation['cwa'] = tes_cwa.series

# %%
f, ax = plt.subplots(figsize=(10, 10))

tessellation.plot(ax=ax, column='cwa', legend=True, scheme='quantiles', k=10, cmap='Greens_r')
plt.title('compactness-weighted axis of each tessellation - Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# ## Covered Area Ratio

# %%
print("Tessellation columns:", tessellation.columns.tolist())
print("Clean buildings columns:", clean_buildings.columns.tolist())

tessellation['area'] = tessellation.geometry.area

# %%
# USING UID

tessellation['uID'] = range(len(tessellation))

# Group buildings by tessellation cell and sum their areas
building_areas = clean_buildings.groupby('uID')['area'].sum()

# Calculate CAR by dividing the summed building areas by tessellation areas
tessellation = tessellation.set_index('uID')
tessellation['CAR'] = building_areas / tessellation['area']
tessellation = tessellation.reset_index()

print(clean_buildings.columns)

# %%
# Group buildings by index and sum their areas
building_areas = clean_buildings.groupby(level=0)['area'].sum()

# Calculate CAR directly using index matching
tessellation['CAR'] = building_areas / tessellation['area']

print(tessellation['CAR'].head())

# %%
f, ax = plt.subplots(figsize=(10, 10))
tessellation.plot(ax=ax, column='CAR', legend=True, scheme='quantiles', k=10, cmap='viridis')
plt.title('Covered Area Ratio Nova Cidade')
clean_buildings.plot(ax=ax, color='white', alpha=0.5)
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Tesselation Area

# %%
tessellation['tes_area'] = tessellation.geometry.area

# %%
f, ax = plt.subplots(figsize=(10, 10))

tessellation.plot(ax=ax, edgecolor='grey', linewidth=0.5, column='tes_area', legend=True, scheme='quantiles', k=10, cmap='magma', alpha=1)
clean_buildings.plot(ax=ax, color='black', alpha=.3)
plt.title('Tesselation Areas Nova Cidade')

ax.set_axis_off()
plt.show()

# %%
print(tessellation.head())

# %% [markdown]
# # Fractal dimension

# %% [markdown]
# A fractal dimension greater than 1 for a 2-dimensional patch indicates a departure
# from euclidean geometry (that is, an increase in shape complexity).

# %%
clean_buildings['fractal'] = momepy.fractal_dimension(clean_buildings)
clean_buildings.fractal[0]

# %%
f, ax = plt.subplots(figsize=(10, 10))
clean_buildings.plot(ax=ax, column='fractal', legend=True, scheme='quantiles', cmap='Wistia')
plt.title('Fractal dimension - Nova Cidade')
ax.set_axis_off()
plt.show()

# %% [markdown]
# # TOPOLOGY METRICS

# %% [markdown]
# # Obtain basic dataset = Centroids of the buildings

# %%
# Centroids of the buildings
def multipolygon_centroid(geom):
    if geom.geom_type == 'MultiPolygon':
        return geom.convex_hull.centroid
    else:
        return geom.centroid

clean_buildings['centroid'] = clean_buildings.geometry.apply(multipolygon_centroid)

# Create a GeoDataFrame for the centroids with uID
centroids_gdf = gpd.GeoDataFrame({
    'uID': clean_buildings['uID'],
    'geometry': clean_buildings['centroid']
}, crs=clean_buildings.crs)

# %%
print(clean_buildings.columns)

# %%
# Plot
f, ax = plt.subplots(figsize=(10, 10))
tessellation.plot(ax=ax, edgecolor='white', linewidth=0.5, facecolor='grey', alpha=.7)
clean_buildings.plot(ax=ax, color='red', alpha=.7)
centroids_gdf.plot(ax=ax, color='black', markersize=0.5, marker='o', label='Centroids')
plt.title('Tessellation out of OSM building footprints + centroids - Nova Cidade')
ax.set_axis_off()
plt.show()

# %%
total_nodes = len(centroids_gdf)
print(f"Total number of nodes: {total_nodes}")
total_buildings = len(clean_buildings)
print(f"Total number of buildings: {total_buildings}")

# %% [markdown]
# # Delaunay Triangulation

# %%
#Coordinates based on the centroids of the buildings
coordinates = np.column_stack((centroids_gdf.geometry.x, centroids_gdf.geometry.y))

from scipy.spatial import Delaunay
tri = Delaunay(coordinates)

# Create a networkx graph out of the Delaunay triangulation
G = nx.Graph()

# Add edges to the graph
for simplex in tri.simplices:
    for i in range(3):
        for j in range(i + 1, 3):
            G.add_edge(simplex[i], simplex[j])

# Get positions of the nodes for plotting
positions = {i: (coordinates[i, 0], coordinates[i, 1]) for i in range(len(coordinates))}

# %%
# Plot
f, ax = plt.subplots(figsize=(10, 10))
tessellation.plot(ax=ax, edgecolor='white', linewidth=0.5, facecolor='grey', alpha=.7)
clean_buildings.plot(ax=ax, color='white', alpha=.7)

# Edges of the Delaunay triangulation
nx.draw(G, pos=positions, node_size=0.1, node_color='red', edge_color='black', width=0.5)
plt.title('Delaunay Triangulation of Nova Cidade buildings')
plt.show()

# %% [markdown]
# # Weighted distance

# %%
# Edges to the graph with weights based on Euclidean distance
for simplex in tri.simplices:
    for i in range(3):
        for j in range(i + 1, 3):
            p1 = coordinates[simplex[i]]
            p2 = coordinates[simplex[j]]
            distance = euclidean(p1, p2) #scipy
            G.add_edge(simplex[i], simplex[j], weight=distance) #networkx

# Extract edges with their weights
edges = []
for u, v, data in G.edges(data=True):
    line = LineString([coordinates[u], coordinates[v]])
    edges.append({'geometry': line, 'weight': data['weight']})

# Geodataframe of edges
gdf_edges = gpd.GeoDataFrame(edges)

# %%
#Plot
f, ax = plt.subplots(figsize=(10, 10))

# centroids_gdf.plot(ax=ax, color='grey', markersize=0.5, marker='o', label='Centroids', zorder=5)

gdf_edges.plot(ax=ax, column='weight', legend=True, scheme='quantiles', k=10, cmap='viridis', linewidth=0.7, zorder=0)

plt.title('Weighted Delaunay Triangulation')
ax.set_axis_off()
plt.show()

# %%
# Initialize a dictionary to store average weighted distances for each node
node_avg_weighted_distance = {}

# Loop through each node in the graph
for node in G.nodes():
    # Get all neighboring nodes (adjacent nodes)
    neighbors = list(G.neighbors(node))

    # Calculate average weighted distance
    total_weighted_distance = 0.0
    count = 0

    # Iterate over edges connecting the node to its neighbors
    for neighbor in neighbors:
        # Get the weight of the edge between node and neighbor
        weight = G[node][neighbor]['weight']

        # Accumulate weighted distance
        total_weighted_distance += weight
        count += 1

    # Calculate average weighted distance for the node
    if count > 0:
        avg_weighted_distance = total_weighted_distance / count
    else:
        avg_weighted_distance = 0.0

    # Store the average weighted distance in the dictionary
    node_avg_weighted_distance[node] = avg_weighted_distance

# Print or use node_avg_weighted_distance as needed
print(node_avg_weighted_distance)

# %%
# Ensure that the GeoDataFrame indices match the graph nodes
centroids_gdf = centroids_gdf.reset_index(drop=True)

# Ensure centroids_gdf has uID as index
# centroids_gdf.set_index('uID', inplace=True)

# Map the average weighted distances to the GeoDataFrame
centroids_gdf['avg_weighted_distance'] = centroids_gdf.index.map(node_avg_weighted_distance)

# Verify the mapping
print(centroids_gdf[['avg_weighted_distance']].head())

# Plot to visualize the average weighted distances
f, ax = plt.subplots(figsize=(10, 10))

# Ensure avg_weighted_distance column exists and is not empty
if 'avg_weighted_distance' in centroids_gdf.columns and not centroids_gdf['avg_weighted_distance'].isnull().all():
    centroids_gdf.plot(ax=ax, column='avg_weighted_distance',  legend=True, scheme='quantiles', cmap='viridis', markersize=5, linewidth=0.5, zorder=5)
    gdf_edges.plot(ax=ax, color='grey', linewidth=0.3, zorder=0)
    plt.title('Average Weighted Distance of Building Centroids')
    ax.set_axis_off()
    plt.show()
else:
    print("Average weighted distance data is missing or empty.")

# %%
total_nodes = len(centroids_gdf)
print(f"Total number of nodes: {total_nodes}")
print(len(clean_buildings))
#same amount of nodes to buildings :)

# %%
print(clean_buildings.columns)

# %% [markdown]
# # Spatial Joint MM and TP

# %%
# Spatial join using geopandas.sjoin
# Merge buildings and centroids_gdf, ensuring we retain the geometry column
# Step 1: Merge clean_buildings with centroids_gdf on uID
buildings_with_centroids = clean_buildings.merge(
    centroids_gdf,
    on='uID',
    how='left',
    suffixes=('_building', '_centroid')
)

# Step 2: Merge the result with tessellation using uID
complete_buildings = buildings_with_centroids.merge(
    tessellation,
    on='uID',
    how='left',
    suffixes=('', '_tessellation')
)

# Step 3: Ensure the geometry column is preserved (or reset if overwritten)
complete_buildings = gpd.GeoDataFrame(
    complete_buildings,
    geometry='geometry_building',  # Replace 'geometry_building' with the correct geometry column if needed
    crs=clean_buildings.crs
)

# Step 4: Validate the resulting GeoDataFrame
print(complete_buildings.head())  # Check the joined result
print(complete_buildings.columns)  # Ensure all expected columns are present

joined_gdf = clean_buildings.join(
    centroids_gdf,
    how='left',
    lsuffix='_building',
    rsuffix='_centroid'
)


# Merge the result with the tessellation DataFrame
# joined_gdf = joined_gdf.merge(tessellation, on='uID', how='left', suffixes=('', '_tessellation'))
# joined_gdf = joined_gdf.merge(tessellation, how='left', suffixes=('', '_tessellation'))

joined_gdf = joined_gdf.join(tessellation, how='left', lsuffix='', rsuffix='_tessellation')

# Check the first few rows to verify the join
print(joined_gdf.head())
# print(joined_gdf.geom_type)

# %% [markdown]
# # GROUND TRUTH DATA

# %%
def classify_and_analyze_favelas(clean_buildings, type_column='tipo', plot=True):
    """
    Classify buildings as favela/not-favela and provide analysis.

    Parameters:
    buildings_gdf (GeoDataFrame): Buildings data
    type_column (str): Name of column containing building type codes
    plot (bool): Whether to create visualization

    Returns:
    GeoDataFrame: Buildings with added classification
    dict: Analysis results
    """
    # Create a copy to avoid modifying original
    buildings_copy = clean_buildings.copy()

    # Add classification - check if type_column contains any number
    buildings_copy['label'] = np.where(
        buildings_copy[type_column].notna(), # Check if there's any value
        'favela',
        'not-favela'
    )

    # Calculate statistics
    stats = {
        'total_buildings': len(buildings_copy),
        'favela_count': (buildings_copy['label'] == 'favela').sum(),
        'non_favela_count': (buildings_copy['label'] == 'not-favela').sum(),
        'unique_types': buildings_copy[type_column].unique().tolist(),
        'type_counts': buildings_copy[type_column].value_counts().to_dict()
    }

    stats['favela_percentage'] = (stats['favela_count'] / stats['total_buildings']) * 100

    # Print analysis
    print("\n=== Favela Classification Analysis ===")
    print(f"Total buildings: {stats['total_buildings']}")
    print(f"Favela buildings: {stats['favela_count']} ({stats['favela_percentage']:.1f}%)")
    print(f"Non-favela buildings: {stats['non_favela_count']}")

    print("\nBuilding type distribution:")
    for type_code, count in stats['type_counts'].items():
        print(f"{type_code}: {count} buildings")

    if plot:
        # Create visualization
        f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))

        # Plot 1: Spatial distribution
        buildings_copy.plot(ax=ax1, column='label', categorical=True,
                          legend=True, cmap='Set3',
                          legend_kwds={'title': 'Classification'})
        ax1.set_title('Spatial Distribution of Favelas')
        ax1.set_axis_off()

        # Plot 2: Classification counts
        pd.Series([stats['favela_count'], stats['non_favela_count']],
                  index=['favela', 'not-favela']).plot(kind='bar', ax=ax2,
                  color=['#FF6347', '#4682B4'])
        ax2.set_title('Favela vs Non-Favela Count')
        ax2.set_xlabel('Building Type')
        ax2.set_ylabel('Count')
        plt.xticks(rotation=0)

        plt.tight_layout()
        plt.show()

    return buildings_copy, stats

# %%
try:
    classified_buildings, analysis = classify_and_analyze_favelas(
        complete_buildings,
        type_column='nome_count'
    )
    ground_truth_gdf = classified_buildings

    # Now you can merge with buildings if needed
    complete_buildings['label'] = classified_buildings['label']

    plt.show()

except Exception as e:
    print(f"Error during classification analysis: {str(e)}")

# %%
print("Buildings with labels:")
print(ground_truth_gdf.head())

# %% [markdown]
# # Classification based on metrics with a stepwise searching between defined ranges

# %%
print(ground_truth_gdf.columns)

# %%
from sklearn.metrics import accuracy_score, classification_report

new_gdf = ground_truth_gdf

# Select features for prediction
X_new = new_gdf[metrics]

# Impute missing values in the new GeoDataFrame using the trained imputer
X_new_imputed = pd.DataFrame(imputer.transform(X_new), columns=X_new.columns)

# Predict using the trained model
new_gdf['predicted_labels'] = rf_model.predict(X_new_imputed)

# Evaluate the predictions if true labels are available
if 'label' in new_gdf:
    y_true_new = new_gdf['label']
    y_pred_new = new_gdf['predicted_labels']

    # Calculate accuracy
    accuracy_new = accuracy_score(y_true_new, y_pred_new) * 100
    print(f"Prediction Accuracy on New Data: {accuracy_new:.2f}%")

    # Generate classification report
    print("Classification Report for New Data:")
    print(classification_report(y_true_new, y_pred_new))

# Plot the predictions
fig, ax = plt.subplots(1, 1, figsize=(12, 12))
new_gdf.plot(column='predicted_labels', cmap='coolwarm', alpha=0.7, legend=True, ax=ax,
             legend_kwds={'loc': 'lower right', 'title': "Predicted Labels"})

# Add scale bar
scalebar = ScaleBar(1, location='lower left', pad=1, box_alpha=0.5)
ax.add_artist(scalebar)

# Add north arrow
x, y, arrow_length = 0.04, 1, 0.08
ax.annotate('N', xy=(x, y), xytext=(x, y-arrow_length),
            arrowprops=dict(facecolor='black', headwidth=15, headlength=20, width=5),
            ha='center', va='center', fontsize=15,
            xycoords=ax.transAxes)

# Add data source text
plt.text(0.5, 0.02, 'Data source: OpenStreetMap', horizontalalignment='center',
         verticalalignment='center', transform=ax.transAxes, fontsize=7)

plt.title('Buildings TS Classification on New Data')
ax.set_axis_off()
plt.show()

# %%
# Evaluate predictions and create a column for correct/incorrect predictions
if 'label' in new_gdf:
    new_gdf['prediction_correct'] = new_gdf['predicted_labels'] == new_gdf['label']

# Plot the predictions
fig, ax = plt.subplots(1, 1, figsize=(12, 12))

# Plot correct predictions in red
new_gdf[new_gdf['prediction_correct']].plot(
    ax=ax, color='red', label='Correct Predictions', alpha=0.7
)

# Plot incorrect predictions in yellow
new_gdf[~new_gdf['prediction_correct']].plot(
    ax=ax, color='yellow', label='Incorrect Predictions', alpha=0.7
)

# Add scale bar
scalebar = ScaleBar(1, location='lower left', pad=1, box_alpha=0.5)
ax.add_artist(scalebar)

# Add north arrow
x, y, arrow_length = 0.04, 1, 0.08
ax.annotate('N', xy=(x, y), xytext=(x, y-arrow_length),
            arrowprops=dict(facecolor='black', headwidth=15, headlength=20, width=5),
            ha='center', va='center', fontsize=15,
            xycoords=ax.transAxes)

# Add legend and title
ax.legend(loc='upper right')
plt.title('Prediction Accuracy Map')
ax.set_axis_off()
plt.show()
